# %% [markdown]
# ## On-policy Approximation of Action Values

# %% [markdown]
# ### **1. Intro**

# %% [markdown]
# * 테이블 형식의 한계
# * 일반화의 어려움. 배우지 못한 상태들에 어떻게 대처할 것인가?

# %% [markdown]
# ### **2. Value Function**
#
# `-` RL과 지도학습의 연결
#
# * incremental learning
# * non-stationarity 처리: 학습 도중에 정답이 계속 바뀜

# %% [markdown]
# ### **3. Gradient-Descent Methods**

# %% [markdown]
# * 데이터가 실시간으로 들어오는 온라인 학습에 적합한 방식
# * 가중치의 수는 가능한 상태보다 훨씬 적기 때문에 어떻게 근사할 것인지만 고려...
# * 가치의 참값을 알 수 없기 때문에, 손실값에 추정치를 고려해야 함
# > 수학적 수렴이 보장됨...
