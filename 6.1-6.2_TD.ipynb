# %% [markdown]
# ## Temporal Difference

# %% [markdown]
# ### **1. TD Prediction**

# %% [markdown]
# * TD(0)
# > step마다 업데이트 수행
# >
# > 시간차 학습
# >
# > 현재 스텝으로 직전 스텝을 학습시킴

# %% [markdown]
# ### **2. Advantages of TD Methods**

# %% [markdown]
# * 단순 MC 방법보다 수렴 속도가 빠름: 학습이 더 많이 됨
